# %% [markdown]
# <a href="https://colab.research.google.com/github/anish2105/Spotify/blob/main/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Highest Charting Position: The highest position that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
#
# Number of Times Charted: The number of times that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
#
# Week of Highest Charting: The week when the song had the Highest Position in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
#
# Song Name: Name of the song that has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
#
# Song iD: The song ID provided by Spotify (unique to each song).
#
# Streams: Approximate number of streams the song has.
#
# Artist: The main artist/ artists involved in making the song.
#
# Artist Followers: The number of followers the main artist has on Spotify.
#
# Genre: The genres the song belongs to.
#
# Release Date: The initial date that the song was released.
#
# Weeks Charted: The weeks that the song has been on in the Spotify Top 200 Weekly Global Charts in 2020 & 2021.
#
# Popularity:The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.
#
# Danceability: Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#
# Acousticness: A measure from 0.0 to 1.0 of whether the track is acoustic.
#
# Energy: Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
#
# Instrumentalness: Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
#
# Liveness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live.
#
# Loudness: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track. Values typical range between -60 and 0 db.
#
# Speechiness: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value.
#
# Tempo: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.
#
# Valence: A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
#
# Chord: The main chord of the song instrumental.

# %%
import seaborn as sns
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (21, 14)

# %%
df = pd.read_excel('spotify_dataset.xlsx')
#df.head()
df= df

# %%
df.isna().any()
# Out:
# Index                        False
# Highest Charting Position    False
# Number of Times Charted      False
# Week of Highest Charting     False
# Song Name                    False
# Streams                      False
# Artist                       False
# Artist Followers             False
# Song ID                      False
# Genre                        False
# Release Date                 False
# Weeks Charted                False
# Popularity                   False
# Danceability                 False
# Energy                       False
# Loudness                     False
# Speechiness                  False
# Acousticness                 False
# Liveness                     False
# Tempo                        False
# Duration (ms)                False
# Valence                      False
# Chord                        False
# dtype: bool

# %%
df.head()
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name     Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48,633,449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 2   2021-06-25--2021-07-02                           good 4 u  40,162,559
# 3   2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
df.describe()
# Out:
#              Index  Highest Charting Position  Number of Times Charted
# count  1556.000000                1556.000000              1556.000000
# mean    778.500000                  87.744216                10.668380
# std     449.322824                  58.147225                16.360546
# min       1.000000                   1.000000                 1.000000
# 25%     389.750000                  37.000000                 1.000000
# 50%     778.500000                  80.000000                 4.000000
# 75%    1167.250000                 137.000000                12.000000
# max    1556.000000                 200.000000               142.000000

# %%
df = df.dropna()

# %%
df.columns
# Out:
# Index(['Index', 'Highest Charting Position', 'Number of Times Charted',
#        'Week of Highest Charting', 'Song Name', 'Streams', 'Artist',
#        'Artist Followers', 'Song ID', 'Genre', 'Release Date', 'Weeks Charted',
#        'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
#        'Chord'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Index                        0
# Highest Charting Position    0
# Number of Times Charted      0
# Week of Highest Charting     0
# Song Name                    0
# Streams                      0
# Artist                       0
# Artist Followers             0
# Song ID                      0
# Genre                        0
# Release Date                 0
# Weeks Charted                0
# Popularity                   0
# Danceability                 0
# Energy                       0
# Loudness                     0
# Speechiness                  0
# Acousticness                 0
# Liveness                     0
# Tempo                        0
# Duration (ms)                0
# Valence                      0
# Chord                        0
# dtype: int64

# %%
df[['Release Date','Weeks Charted','Popularity' ]] 
#checking if cleaning is required or not
# Out:
#      Release Date                                      Weeks Charted  \
# 0      2017-12-08  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 1      2021-07-09  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 2      2021-05-21  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 3      2021-06-25  2021-07-23--2021-07-30\n2021-07-16--2021-07-23...
# 4      2021-07-23                             2021-07-23--2021-07-30
# ...           ...                                                ...
# 1551   2017-06-02                             2019-12-27--2020-01-03
# 1552   2019-10-11                             2019-12-27--2020-01-03
# 1553   2018-01-12                             2019-12-27--2020-01-03
# 1554   2019-09-25                             2019-12-27--2020-01-03
# 1555   2019-11-13                             2019-12-27--2020-01-03
#
#      Popularity
# 0           100
# 1            99
# 2            99
# 3            98
# 4            96
# ...         ...
# ...

# %%
#checking if there are any missing elements
df['Song ID'].dropna().value_counts().head(30)
# Out:
#                           11
# 5uEYRdEIh9Bo4fpjDd4Na9     3
# 4S2uhQE8L9V6p7rj7SiauJ     2
# 35UUpTmrcFXNIVIN26ujXl     2
# 2YpeDb67231RjR0MgVLzsG     2
# 4lUmnwRybYH7mMzf16xB0y     2
# 0oQc0F6KUE7QY7k5TU6bic     2
# 7wsmIIm0xWmtP7TmACXkJn     2
# 1iQDltZqI7BXnHrFy4Qo1k     2
# 1D3z6HTiQsNmZxjl7F7eoG     2
# 2MbdDtCv5LUVjYy9RuGTgC     2
# 0GzuHFG4Ql6DoyxFRnIk3F     2
# 1SV1fxF65n9NhRHp3KlBuu     2
# 37BZB0z9T8Xu7U3e65qxFy     2
# 4umIPjkehX1r7uhmGvXiSV     2
# 3yZCjDTxzZxx1kll1sRjGc     2
# 0t3ZvGKlmYmVsDzBJAXK8C     2
# 7ygpwy2qP3NbrxVkHvUhXY     2
# 1WedZeiezCmCEOzLwhx0hV     2
# 463CkQjx2Zk1yXoBuierM9     2
# 02kDW379Yfd5PzW5A6vuGt     2
# 73O30uMI7n6DuzBmbtO7kC     2
# 0e6NlGJxYlHvAN8SKxad7N     2
# 5VwwpU7KsLhgfbMEecedhJ     2
# 6uvMKqNlrSvcC4NaKnrwjZ     2
# 4ZRrLHqzhGRXYj2qcB4s5S     2
# 27RSJHEA99Y0Vsow7nA37A     2
# 2AlYncTpVHKwHb55F9lF6O     2
# 07Oz5StQ7GRoygNLaXs2pd     2
# 5kkaSMcf4BFlhRRICCKZb6     1
# Name: Song ID, dtype: int64

# %% [markdown]
# 11 entries have no values, only 1 has been unique remaining are been repeated twice or thrice

# %%
# The songs havn't ID and features 
df[df['Song ID'] == ' '].sort_values(by='Streams')
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 654     655                         73                        1
# 35       36                         36                        1
# 784     785                         76                       14
# 1538   1539                        176                        1
# 876     877                        164                        4
# 750     751                         19                       20
# 163     164                          5                       39
# 1140   1141                        131                        1
# 530     531                         20                        5
# 464     465                        118                        1
# 636     637                         22                        6
#
#      Week of Highest Charting  \
# 654    2020-12-18--2020-12-25
# 35     2021-07-23--2021-07-30
# 784    2020-09-04--2020-09-11
# 1538   2020-01-03--2020-01-10
# 876    2020-09-18--2020-09-25
# ...

# %%
df[df['Song ID'] == ' ']
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 35       36                         36                        1
# 163     164                          5                       39
# 464     465                        118                        1
# 530     531                         20                        5
# 636     637                         22                        6
# 654     655                         73                        1
# 750     751                         19                       20
# 784     785                         76                       14
# 876     877                        164                        4
# 1140   1141                        131                        1
# 1538   1539                        176                        1
#
#      Week of Highest Charting  \
# 35     2021-07-23--2021-07-30
# 163    2020-10-30--2020-11-06
# 464    2021-03-26--2021-04-02
# 530    2021-01-15--2021-01-22
# 636    2020-12-18--2020-12-25
# ...

# %% [markdown]
# we see that when sorted by streams, the highest streams is added first but has no id where as is second case we are just checking it in order of how the data is been present.

# %%
clean_spotify = df.drop(columns = ['Index','Weeks Charted','Chord','Release Date','Week of Highest Charting','Song ID','Genre'],axis=1)
clean_spotify.head(10)
#checking the first 10 values
# Out:
#    Highest Charting Position  Number of Times Charted  \
# 0                          1                        8
# 1                          2                        3
# 2                          1                       11
# 3                          3                        5
# 4                          5                        1
# 5                          1                       18
# 6                          3                       16
# 7                          2                       10
# 8                          3                        8
# 9                          8                       10
#
#                            Song Name     Streams          Artist  \
# 0                            Beggin'  48,633,449        Måneskin
# 1          STAY (with Justin Bieber)  47,248,719   The Kid LAROI
# 2                           good 4 u  40,162,559  Olivia Rodrigo
# 3                         Bad Habits  37,799,456      Ed Sheeran
# ...

# %%
#636, 634 twice christmas is there
# I was checking the data I noticed two songs without an ID with the word "Christmas" 
#and from the data only a week of Highest Charting and Streams for one of them.
# its mostly during christas and quite expected

# %%
df[df['Artist'] == 'Chris Rea'].sort_values(by=['Song Name'])
# Out:
#      Index  Highest Charting Position  Number of Times Charted  \
# 636    637                         22                        6
#
#     Week of Highest Charting                                   Song Name  \
# 636   2020-12-18--2020-12-25  Driving Home for Christmas - 2019 Remaster
#
#        Streams     Artist Artist Followers Song ID Genre  ... Danceability  \
# 636  8,804,531  Chris Rea                                 ...
#
#     Energy Loudness Speechiness Acousticness Liveness Tempo Duration (ms)  \
# 636
#
#     Valence Chord
# 636
#
# [1 rows x 23 columns]

# %%
df[df['Artist'] == 'Queen'].sort_values(by=['Song Name'])
# Out:
#      Index  Highest Charting Position  Number of Times Charted  \
# 178    179                        138                       22
# 141    142                         81                       81
# 612    613                        138                       13
# 654    655                         73                        1
#
#     Week of Highest Charting                                     Song Name  \
# 178   2021-04-02--2021-04-09  Another One Bites The Dust - Remastered 2011
# 141   2019-12-27--2020-01-03           Bohemian Rhapsody - Remastered 2011
# 612   2019-12-27--2020-01-03           Don't Stop Me Now - Remastered 2011
# 654   2020-12-18--2020-12-25   Thank God It's Christmas - Non-Album Single
#
#         Streams Artist Artist Followers                 Song ID  \
# 178   5,204,983  Queen         35888760  57JVGBtBLCfHw2muk5416J
# 141   5,756,583  Queen         35888760  7tFiyTwD0nx5a1eklYtX2J
# 612   4,630,572  Queen         35910149  7hQJA50XrCWABAu5v6QZ4i
# ...

# %%
# extract start and end date of week
df[['Week of Highest Charting_start','Week of Highest Charting_end']] = df['Week of Highest Charting'].str.split('--', expand=True)

# %%
cols = list(df.columns.values)
cols = ['Highest Charting Position',
 'Number of Times Charted',
 'Week of Highest Charting',
 'Week of Highest Charting_start',
 'Week of Highest Charting_end',
 'Song Name',
 'Streams',
 'Artist',
 'Artist Followers',
 'Song ID',
 'Genre',
 'Release Date',
 'Weeks Charted',
 'Popularity',
 'Danceability',
 'Energy',
 'Loudness',
 'Speechiness',
 'Acousticness',
 'Liveness',
 'Tempo',
 'Duration (ms)',
 'Valence',
 'Chord']

# %%
df1=df[cols]

# %%
df1.head()
# Out:
#    Highest Charting Position  Number of Times Charted  \
# 0                          1                        8
# 1                          2                        3
# 2                          1                       11
# 3                          3                        5
# 4                          5                        1
#
#   Week of Highest Charting Week of Highest Charting_start  \
# 0   2021-07-23--2021-07-30                     2021-07-23
# 1   2021-07-23--2021-07-30                     2021-07-23
# 2   2021-06-25--2021-07-02                     2021-06-25
# 3   2021-07-02--2021-07-09                     2021-07-02
# 4   2021-07-23--2021-07-30                     2021-07-23
#
#   Week of Highest Charting_end                          Song Name     Streams  \
# 0                   2021-07-30                            Beggin'  48,633,449
# 1                   2021-07-30          STAY (with Justin Bieber)  47,248,719
# ...

# %%
df['Artist'].value_counts()
# Out:
# Taylor Swift                     52
# Lil Uzi Vert                     32
# Justin Bieber                    32
# Juice WRLD                       30
# Pop Smoke                        29
#                                  ..
# Chris Brown, Young Thug           1
# Rauw Alejandro, J Balvin          1
# 347aidan                          1
# Migrantes, Alico                  1
# Dadá Boladão, Tati Zaqui, OIK     1
# Name: Artist, Length: 716, dtype: int64

# %%
df['Artist'].nunique()
# returns the number of unique values for each column
# Out:
# 716

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8,4))
plt.title('No. of distinct songs by each artist ', fontsize=14)
g = sns.countplot(df['Artist'].value_counts(ascending=True).values)
# g.bar_label(g.containers[0], fmt='%.0f', fontsize=8)
plt.show()

# %% [markdown]
# we see that out of 716 artists where 546 just have just one song in the top 100, while 2 have 64 as so on..

# %% [markdown]
# # Which are the artists with more than one song in the top?

# %%
df_art = df['Artist'].value_counts()

# %%
top_art = df_art[df_art > 1]
top_art
# Out:
# Taylor Swift         52
# Lil Uzi Vert         32
# Justin Bieber        32
# Juice WRLD           30
# Pop Smoke            29
#                      ..
# Marshmello            2
# The Neighbourhood     2
# Cardi B               2
# Gusttavo Lima         2
# Madison Beer          2
# Name: Artist, Length: 170, dtype: int64

# %%
least_streamed =df[df.Streams == df.Streams.min()]

# %%
least_streamed[["Song Name", "Artist", "Streams"]]
# Out:
#               Song Name Artist     Streams
# 1380  Louder than bombs    BTS  10,016,907

# %% [markdown]
# we see that Louder than bombs by BTS has least no of streams in the top 200

# %%
#here we sort dataframe based on "Number of Times Charted", 
#but also group by artist and sum numbers of times charted for each of the artist
df_nu=df.groupby('Artist').sum().sort_values('Number of Times Charted', ascending=False)
df_nu=df_nu.reset_index()
df_nu
# Out:
#                     Artist  Index  Highest Charting Position  \
# 0            Billie Eilish  13908                       1136
# 1               Juice WRLD  25342                       1755
# 2             Harry Styles   1990                        139
# 3               Ed Sheeran   4440                        657
# 4                Pop Smoke  17702                       2420
# ..                     ...    ...                        ...
# 711          KALIM, Ufo361   1143                        183
# 712  Kane Brown, blackbear    231                        187
# 713                Kehlani   1191                        177
# 714     Kygo, Donna Summer    897                        194
# 715               Kontra K   1033                        129
#
#      Number of Times Charted
# 0                        432
# 1                        431
# 2                        364
# 3                        314
# 4                        308
# ..                       ...
# ...

# %%
plt.figure(figsize=(18,10))
plt.title("Top 10 Artists with Highest Numbers of Times Charted")
sns.barplot(x='Artist',y='Number of Times Charted',data=df_nu.head(10))

# %%
#clean data

df=df.fillna('')
df=df.replace(' ', '')
df['Streams']=df['Streams'].str.replace(',','')

#convert all numeric columns to numeric

df[['Highest Charting Position', 'Number of Times Charted', 'Streams', 'Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
       ]] = df[['Highest Charting Position', 'Number of Times Charted', 'Streams','Popularity', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Liveness', 'Tempo', 'Duration (ms)', 'Valence',
       ]].apply(pd.to_numeric)

# %%
#let's also separate year from the column "Release date"
df['Release Year'] = pd.DatetimeIndex(df['Release Date']).year

# %%
dfyear=df.groupby('Release Year').sum().sort_values('Number of Times Charted', ascending=False)
dfyear=dfyear.reset_index()

# %%
#Plotting Barchart about artist and their followers
plt.figure(figsize=(20,8))
plt.title("Years with Highest Numbers of Times Charted")
sns.barplot(x='Release Year',y='Number of Times Charted',data=dfyear.head(10))

# %% [markdown]
# We see that most data comes from 2020, and sice 2021 is ongoing we have a bit less data for this year

# %%
# %matplotlib inline
plt.figure(figsize=(20,16))
artistbh = df.groupby("Artist")['Popularity'].sum().sort_values(ascending=False)[:15]
axis = sns.barplot(artistbh.index, artistbh)
axis.set_title('Top 15 Artists by Popularity')
axis.set_ylabel('Popularity')
plt.show()

# %%
sns.scatterplot(x=df.Streams, y=df.Popularity, s=50)
plt.xlabel('No. of times streamed')
plt.ylabel('Popularity Ranking');

# %%
popularity_mean = df.Popularity.mean()

# %%
least_popular = df[df.Popularity < popularity_mean]

# %%
least_popular
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 53       54                         40                       14
# 65       66                          2                       83
# 83       84                         76                        3
# 95       96                         96                        4
# 118     119                          5                       21
# ...     ...                        ...                      ...
# 1547   1548                        156                        1
# 1550   1551                        190                        1
# 1552   1553                        196                        1
# 1554   1555                        198                        1
# 1555   1556                        199                        1
#
#      Week of Highest Charting                           Song Name  Streams  \
# 53     2021-06-18--2021-06-25                            Rasputin  9600707
# ...

# %%
len(least_popular)
# Out:
# 645

# %%
mean_streams =df.Streams.mean()

# %%
more_streamed = df[df.Streams > mean_streams]

# %%
more_streamed
# Out:
#       Index  Highest Charting Position  Number of Times Charted  \
# 0         1                          1                        8
# 1         2                          2                        3
# 2         3                          1                       11
# 3         4                          3                        5
# 4         5                          5                        1
# ...     ...                        ...                      ...
# 1511   1512                         90                        1
# 1512   1513                        107                        1
# 1513   1514                        111                        1
# 1543   1544                         59                        1
# 1544   1545                         72                        1
#
#      Week of Highest Charting                          Song Name   Streams  \
# 0      2021-07-23--2021-07-30                            Beggin'  48633449
# ...

# %% [markdown]
# **Machine Learning**

# %% [markdown]
# **Things Done in this part**
#
#
#
# 1.   Removing unwanted columns
# 2.   Dealing with Nan Values
# 3.   Dealing with Highly Correlated Features
# 4.   Dealing with Outliers

# %%
df.head(5)
# Out:
#    Index  Highest Charting Position  Number of Times Charted  \
# 0      1                          1                        8
# 1      2                          2                        3
# 2      3                          1                       11
# 3      4                          3                        5
# 4      5                          5                        1
#
#   Week of Highest Charting                          Song Name   Streams  \
# 0   2021-07-23--2021-07-30                            Beggin'  48633449
# 1   2021-07-23--2021-07-30          STAY (with Justin Bieber)  47248719
# 2   2021-06-25--2021-07-02                           good 4 u  40162559
# 3   2021-07-02--2021-07-09                         Bad Habits  37799456
# 4   2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33948454
#
#            Artist Artist Followers                 Song ID  \
# 0        Måneskin          3377762  3Wrjm47oTz2sjIgck11l5e
# ...

# %%
df.columns.value_counts().sum()
# Out:
# 26

# %% [markdown]
# **Removing Unwanted Columns**

# %%
data = df.drop(['Index' , 'Song Name',  'Artist','Number of Times Charted',
       'Artist Followers', 'Song ID', 'Genre', 'Release Date','Chord', 'Week of Highest Charting_start',
       'Week of Highest Charting_end', 'Release Year', 'Duration (ms)','Week of Highest Charting','Weeks Charted'] , axis = 1)

# %%
data
# Out:
#       Highest Charting Position   Streams  Popularity  Danceability  Energy  \
# 0                             1  48633449       100.0         0.714   0.800
# 1                             2  47248719        99.0         0.591   0.764
# 2                             1  40162559        99.0         0.563   0.664
# 3                             3  37799456        98.0         0.808   0.897
# 4                             5  33948454        96.0         0.736   0.704
# ...                         ...       ...         ...           ...     ...
# 1551                        195   4630675        79.0         0.762   0.700
# 1552                        196   4623030        66.0         0.528   0.870
# 1553                        197   4620876        81.0         0.765   0.523
# 1554                        198   4607385        60.0         0.832   0.550
# 1555                        199   4595450        70.0         0.448   0.603
#
# ...

# %% [markdown]
# **Dealing with Nan Values**

# %%
data.isna().sum()
# Out:
# Highest Charting Position     0
# Streams                       0
# Popularity                   11
# Danceability                 11
# Energy                       11
# Loudness                     11
# Speechiness                  11
# Acousticness                 11
# Liveness                     11
# Tempo                        11
# Valence                      11
# dtype: int64

# %% [markdown]
# Mean: The mean is the sum of all the values in the dataset divided by the number of values. It is a good choice when the data is roughly normally distributed and there are no outliers. Using the mean will not be a good choice if the dataset has outliers, as it will be skewed by the large values.
#
# Median: The median is the middle value of a dataset, when the values are sorted in order. It is a good choice when the data is not normally distributed and there are outliers. The median is less affected by outliers than the mean.
#
# Mode: The mode is the most frequent value in the dataset. It is a good choice when the data is categorical or nominal, and the missing value is in a categorical variable. Mode is not useful when the data is continuous.

# %%
for i in data.columns:
  sns.boxplot(x = data[i])
  plt.show()

# %%
for i in data.columns:
  sns.distplot( data[i] , kde = True)
  plt.show()

# %% [markdown]
# As many of the distplot indicate that distribution is not normal distribution and it is skewed distribution, so we can replace all the nan values with median of the particular column

# %%
data.fillna(data.median(), inplace=True)

# %% [markdown]
# or

# %%
# for column in df.columns:
#     # find the median of the column
#     median = data[column].median()
#     # replace NaN values in the column with the median
#     data[column].fillna(median, inplace=True)
#     # check if there are still any NaN values in the column
#     print(f'{column} NaN count: {data[column].isnull().sum()}')

# %%
data.isna().sum()
# Out:
# Highest Charting Position    0
# Streams                      0
# Popularity                   0
# Danceability                 0
# Energy                       0
# Loudness                     0
# Speechiness                  0
# Acousticness                 0
# Liveness                     0
# Tempo                        0
# Valence                      0
# dtype: int64

# %%
median = data['Popularity'].median()
print(median)
median2 = data['Danceability'].median()
print(median2)
# Out:
# 73.0
# 0.707

# %% [markdown]
# **Dealing With Highly Correlated Features**

# %%
data.corr()
# Out:
#                            Highest Charting Position   Streams  Popularity  \
# Highest Charting Position                   1.000000 -0.295801   -0.163779
# Streams                                    -0.295801  1.000000    0.123116
# Popularity                                 -0.163779  0.123116    1.000000
# Danceability                                0.016917 -0.081032    0.028585
# Energy                                      0.062712  0.004185    0.094747
# Loudness                                    0.031843 -0.030967    0.158923
# Speechiness                                 0.041658 -0.062857   -0.032622
# Acousticness                               -0.012382  0.033659   -0.091650
# Liveness                                    0.013214  0.041645   -0.029956
# Tempo                                       0.026173  0.053338   -0.024983
# Valence                                     0.045206  0.038301   -0.000969
#
# ...

# %%
plt.figure(figsize = (20,15))
dataplot = sns.heatmap(data.corr() , annot = True)
plt.show()

# %%
for i , r in data.corr().iterrows():
    print(i)
    print(r)
# Out:
# Highest Charting Position
# Highest Charting Position    1.000000
# Streams                     -0.295801
# Popularity                  -0.163779
# Danceability                 0.016917
# Energy                       0.062712
# Loudness                     0.031843
# Speechiness                  0.041658
# Acousticness                -0.012382
# Liveness                     0.013214
# Tempo                        0.026173
# Valence                      0.045206
# Name: Highest Charting Position, dtype: float64
# Streams
# Highest Charting Position   -0.295801
# Streams                      1.000000
# Popularity                   0.123116
# Danceability                -0.081032
# Energy                       0.004185
# Loudness                    -0.030967
# Speechiness                 -0.062857
# Acousticness                 0.033659
# Liveness                     0.041645
# Tempo                        0.053338
# Valence                      0.038301
# Name: Streams, dtype: float64
# ...

# %%
corr_features = []
for i , r in data.corr().iterrows():
  k = 0
  for j in range(len(r)):
    if i != r.index[k]:
      if r.values[k] >= 0.5  :
        corr_features.append([i,r.index[k],r.values[k]])
    k += 1
corr_features
# Out:
# [['Energy', 'Loudness', 0.7326095056712454],
#  ['Loudness', 'Energy', 0.7326095056712454]]

# %% [markdown]
# As they correlation values is not greater than 0.8, so there is no problem of high correlated values.
#
# But if we had correlated values then we can use the following code to eliminate it

# %%
# feat = []
# for i in corr_features:
#     if i[2] >= 0.8:
#         feat.append(i[0])
#         feat.append(i[1])
        
# data.drop(list(set(feat)) , axis = 1 , inplace = True)

# %% [markdown]
# **Finding the outliers**

# %%
def calc_interquartile(data,column):
    global lower, upper
    #calculating the first and third quartile
    first_quartile , third_quartile = np.percentile(data[column] , 25) , np.percentile(data[column] , 75)
    #calculate the interquartilerange
    iqr  = third_quartile - first_quartile
    # outlier cutoff (1.5 is a generally taken as a threshold)
    cutoff = iqr *1.5
    #calculate the lower and upper limits
    lower , upper = first_quartile - cutoff , third_quartile + cutoff
     #remove the outliers from the columns
    upper_outliers = data[data[column] > upper]
    lower_outliers = data[data[column] < lower]
    print('Lower outliers' , lower_outliers.shape[0])
    print('Lower outliers' , upper_outliers.shape[0])
    return print('total outliers' , upper_outliers.shape[0] + lower_outliers.shape[0])

# %%
for i in data.columns:
  print(i)
  calc_interquartile(data , i)
# Out:
# Highest Charting Position
# Lower outliers 0
# Lower outliers 0
# total outliers 0
# Streams
# Lower outliers 0
# Lower outliers 171
# total outliers 171
# Popularity
# Lower outliers 60
# Lower outliers 0
# total outliers 60
# Danceability
# Lower outliers 11
# Lower outliers 0
# total outliers 11
# Energy
# Lower outliers 17
# Lower outliers 0
# total outliers 17
# Loudness
# Lower outliers 52
# Lower outliers 2
# total outliers 54
# Speechiness
# Lower outliers 0
# Lower outliers 105
# total outliers 105
# Acousticness
# Lower outliers 0
# Lower outliers 36
# total outliers 36
# Liveness
# Lower outliers 0
# Lower outliers 108
# total outliers 108
# Tempo
# Lower outliers 0
# Lower outliers 0
# total outliers 0
# Valence
# Lower outliers 0
# Lower outliers 0
# total outliers 0

# %%
for cols in data.columns:
    Q1 = data[cols].quantile(0.25)
    Q3 = data[cols].quantile(0.75)
    iqr = Q3 - Q1

    low = Q1-1.5*iqr
    high = Q3+1.5*iqr
    data.loc[(data[cols] < low) | (data[cols] > high), cols] = data[cols].median()

# %%
for i in data.columns:
  print(i)
  calc_interquartile(data , i)
# Out:
# Highest Charting Position
# Lower outliers 0
# Lower outliers 0
# total outliers 0
# Streams
# Lower outliers 0
# Lower outliers 0
# total outliers 0
# Popularity
# Lower outliers 5
# Lower outliers 0
# total outliers 5
# Danceability
# Lower outliers 4
# Lower outliers 0
# total outliers 4
# Energy
# Lower outliers 1
# Lower outliers 0
# total outliers 1
# Loudness
# Lower outliers 3
# Lower outliers 0
# total outliers 3
# Speechiness
# Lower outliers 0
# Lower outliers 35
# total outliers 35
# Acousticness
# Lower outliers 0
# Lower outliers 39
# total outliers 39
# Liveness
# Lower outliers 0
# Lower outliers 51
# total outliers 51
# Tempo
# Lower outliers 0
# Lower outliers 0
# total outliers 0
# Valence
# Lower outliers 0
# Lower outliers 0
# total outliers 0

# %%
for i in data.columns:
  sns.boxplot(x = data[i])
  plt.show()
